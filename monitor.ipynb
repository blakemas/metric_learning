# %%
import matplotlib.pyplot as plt 
from dask.distributed import Client
client = Client('54.210.213.191:8786')

# %%
client.has_what()
# Out:
# {'tcp://172.31.49.6:32965': [],
#  'tcp://172.31.49.6:33511': [],
#  'tcp://172.31.49.6:33527': [],
#  'tcp://172.31.49.6:34970': [],
#  'tcp://172.31.49.6:35089': [],
#  'tcp://172.31.49.6:35462': [],
#  'tcp://172.31.49.6:35468': [],
#  'tcp://172.31.49.6:35960': [],
#  'tcp://172.31.49.6:36083': [],
#  'tcp://172.31.49.6:36472': [],
#  'tcp://172.31.49.6:36768': [],
#  'tcp://172.31.49.6:36798': [],
#  'tcp://172.31.49.6:37196': [],
#  'tcp://172.31.49.6:37638': [],
#  'tcp://172.31.49.6:37658': [],
#  'tcp://172.31.49.6:39273': [],
#  'tcp://172.31.49.6:39799': [],
#  'tcp://172.31.49.6:40517': [],
#  'tcp://172.31.49.6:40931': [],
#  'tcp://172.31.49.6:42267': [],
#  'tcp://172.31.49.6:42602': [],
#  'tcp://172.31.49.6:43411': [],
#  'tcp://172.31.49.6:43720': [],
#  'tcp://172.31.49.6:43804': [],
#  'tcp://172.31.49.6:44093': [],
#  'tcp://172.31.49.6:45886': [],
#  'tcp://172.31.49.6:46148': [],
#  'tcp://172.31.49.6:46702': [],
#  'tcp://172.31.49.6:48145': [],
# ...

# %%
client.who_has()
# Out:
# {}

# %%
c
